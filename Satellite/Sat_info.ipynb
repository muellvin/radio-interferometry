# %% [markdown]
# # List of Satellite with respective height and time of culmination pass

# %%
from skyfield.api import Topos, load, EarthSatellite
from datetime import datetime
import requests
from datetime import timedelta

# %%
from skyfield.api import Topos, load, EarthSatellite
from datetime import datetime
import requests


# Function to download TLE data from CelesTrak
def download_tle():
    url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=active&FORMAT=tle'
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful
    tle_lines = response.text.strip().splitlines()
    return tle_lines

# Load satellites using EarthSatellite class
def load_satellites(tle_lines):
    satellites = []
    for i in range(0, len(tle_lines), 3):
        name = tle_lines[i].strip()
        if "STARLINK" not in name.upper():  # Exclude Starlink satellites
            line1 = tle_lines[i + 1].strip()
            line2 = tle_lines[i + 2].strip()
            satellite = EarthSatellite(line1, line2, name, load.timescale())
            satellites.append(satellite)
    return satellites

# Function to predict satellite culmination passes for a given location and time range
def predict_passes(satellites, location, start_time, end_time):
    ts = load.timescale()
    observer = Topos(latitude_degrees=location[0], longitude_degrees=location[1])

    results = []  # List to store results for sorting
    print(f"Predicting satellite culminations for location: {location}")
    for satellite in satellites:
        t, events = satellite.find_events(observer, start_time, end_time, altitude_degrees=30.0)
        for ti, event in zip(t, events):
            if event == 1:  # 1 corresponds to 'culminate'
                # Calculate satellite altitude during culmination
                difference = satellite - observer
                topocentric = difference.at(ti)
                altitude = topocentric.distance().km  # Altitude in kilometers
                
                # Append result as a tuple (satellite name, time, altitude)
                results.append((satellite.name, ti.utc_strftime('%Y-%m-%d %H:%M:%S'), altitude))

    # Sort results by altitude
    results.sort(key=lambda x: x[2], reverse=True)  # Sort by altitude in descending order

    # Display sorted results
    for name, time, altitude in results:
        print(f"{name} culminate at {time} UTC, altitude: {altitude:.2f} km")

# Main function
if __name__ == "__main__":
    # Download and load TLE data
    #tle_lines = download_tle()
    satellites = load_satellites(tle_lines)

    # Set location for Zurich, Switzerland (latitude, longitude)
    location = (47.3769, 8.5417)

    # Set prediction time range (8 Jan 2025, 01:00 UTC to 8 Jan 2025, 02:00 UTC)
    ts = load.timescale()
    start_time = ts.utc(2025, 1, 7, 17, 15, 0)  # 8 Jan 2025, 01:00 UTC
    end_time = ts.utc(2025, 1, 7, 17, 40, 0)    # 8 Jan 2025, 02:00 UTC

    # Predict satellite culmination passes
    predict_passes(satellites, location, start_time, end_time)
# Out:
# Predicting satellite culminations for location: (47.3769, 8.5417)
# THOR 5 culminate at 2025-01-07 17:38:50 UTC, altitude: 38182.09 km
# BEIDOU-2 IGSO-3 culminate at 2025-01-07 17:25:50 UTC, altitude: 38176.88 km
# ARKTIKA-M 2 culminate at 2025-01-07 17:20:41 UTC, altitude: 28707.84 km
# GSAT0203 (GALILEO 7) culminate at 2025-01-07 17:20:15 UTC, altitude: 23443.79 km
# NAVSTAR 78 (USA 293) culminate at 2025-01-07 17:19:28 UTC, altitude: 20447.65 km
# NAVSTAR 73 (USA 260) culminate at 2025-01-07 17:28:19 UTC, altitude: 20349.45 km
# COSMOS 2522 [GLONASS-M] culminate at 2025-01-07 17:17:33 UTC, altitude: 19275.52 km
# COSMOS 2545 [GLONASS-M] culminate at 2025-01-07 17:35:57 UTC, altitude: 19265.79 km
# LAGEOS 1 culminate at 2025-01-07 17:30:05 UTC, altitude: 7197.85 km
# LAGEOS 2 culminate at 2025-01-07 17:25:29 UTC, altitude: 6001.22 km
# EXPRESS-MD2 culminate at 2025-01-07 17:21:28 UTC, altitude: 2586.05 km
# GLOBALSTAR M085 culminate at 2025-01-07 17:18:40 UTC, altitude: 2238.58 km
# COSMOS 2386 culminate at 2025-01-07 17:38:35 UTC, altitude: 2082.15 km
# COSMOS 2532 culminate at 2025-01-07 17:26:08 UTC, altitude: 2080.78 km
# GLOBALSTAR M077 culminate at 2025-01-07 17:24:38 UTC, altitude: 2034.72 km
# GLOBALSTAR M087 culminate at 2025-01-07 17:25:07 UTC, altitude: 2011.56 km
# ONEWEB-0180 culminate at 2025-01-07 17:23:14 UTC, altitude: 2008.68 km
# ONEWEB-0191 culminate at 2025-01-07 17:25:29 UTC, altitude: 1973.03 km
# ONEWEB-0665 culminate at 2025-01-07 17:27:44 UTC, altitude: 1939.80 km
# ONEWEB-0208 culminate at 2025-01-07 17:29:59 UTC, altitude: 1903.11 km
# ONEWEB-0661 culminate at 2025-01-07 17:32:16 UTC, altitude: 1870.88 km
# ONEWEB-0204 culminate at 2025-01-07 17:33:25 UTC, altitude: 1851.21 km
# ONEWEB-0189 culminate at 2025-01-07 17:34:31 UTC, altitude: 1832.98 km
# ONEWEB-0638 culminate at 2025-01-07 17:36:45 UTC, altitude: 1802.95 km
# YAOGAN-27 culminate at 2025-01-07 17:29:17 UTC, altitude: 1802.03 km
# ONEWEB-0209 culminate at 2025-01-07 17:39:01 UTC, altitude: 1766.52 km
# ONEWEB-0637 culminate at 2025-01-07 17:39:53 UTC, altitude: 1713.73 km
# ONEWEB-0235 culminate at 2025-01-07 17:37:36 UTC, altitude: 1683.79 km
# ONEWEB-0226 culminate at 2025-01-07 17:35:17 UTC, altitude: 1650.88 km
# GONETS-M 13 culminate at 2025-01-07 17:15:22 UTC, altitude: 1645.55 km
# COSMOS 2385 culminate at 2025-01-07 17:23:23 UTC, altitude: 1620.46 km
# ONEWEB-0647 culminate at 2025-01-07 17:33:00 UTC, altitude: 1618.17 km
# MAROC-TUBSAT culminate at 2025-01-07 17:28:36 UTC, altitude: 1616.64 km
# ONEWEB-0222 culminate at 2025-01-07 17:31:50 UTC, altitude: 1605.27 km
# GLOBALSTAR M071 culminate at 2025-01-07 17:29:16 UTC, altitude: 1604.84 km
# ONEWEB-0231 culminate at 2025-01-07 17:30:42 UTC, altitude: 1587.67 km
# ONEWEB-0242 culminate at 2025-01-07 17:28:24 UTC, altitude: 1560.97 km
# PALISADE culminate at 2025-01-07 17:16:30 UTC, altitude: 1530.91 km
# ONEWEB-0651 culminate at 2025-01-07 17:26:04 UTC, altitude: 1529.48 km
# HULIANWANG JISHU SHIYAN* culminate at 2025-01-07 17:16:42 UTC, altitude: 1508.98 km
# ONEWEB-0239 culminate at 2025-01-07 17:23:47 UTC, altitude: 1502.94 km
# ONEWEB-0223 culminate at 2025-01-07 17:21:30 UTC, altitude: 1476.54 km
# GLOBALSTAR M076 culminate at 2025-01-07 17:36:13 UTC, altitude: 1450.51 km
# ONEWEB-0718 culminate at 2025-01-07 17:19:13 UTC, altitude: 1449.21 km
# ONEWEB-0006 culminate at 2025-01-07 17:18:03 UTC, altitude: 1437.44 km
# ONEWEB-0216 culminate at 2025-01-07 17:16:54 UTC, altitude: 1423.60 km
# GLOBALSTAR M070 culminate at 2025-01-07 17:24:22 UTC, altitude: 1420.51 km
# RAPTOR1 culminate at 2025-01-07 17:20:35 UTC, altitude: 1356.57 km
# RAPTOR4 culminate at 2025-01-07 17:37:36 UTC, altitude: 1332.59 km
# HBTSS-SV1 culminate at 2025-01-07 17:36:48 UTC, altitude: 1332.18 km
# 2022-023E culminate at 2025-01-07 17:37:53 UTC, altitude: 1329.96 km
# YAOGAN-25 01A culminate at 2025-01-07 17:32:30 UTC, altitude: 1318.48 km
# IRIDIUM 117 culminate at 2025-01-07 17:19:40 UTC, altitude: 1305.41 km
# ONEWEB-0381 culminate at 2025-01-07 17:15:38 UTC, altitude: 1294.94 km
# ONEWEB-0556 culminate at 2025-01-07 17:17:54 UTC, altitude: 1278.22 km
# YAOGAN-25 01B culminate at 2025-01-07 17:25:36 UTC, altitude: 1272.93 km
# ONEWEB-0372 culminate at 2025-01-07 17:19:57 UTC, altitude: 1262.69 km
# ONEWEB-0377 culminate at 2025-01-07 17:20:23 UTC, altitude: 1259.00 km
# YAOGAN-25 01C culminate at 2025-01-07 17:23:59 UTC, altitude: 1255.06 km
# YUNHAI-2 05 culminate at 2025-01-07 17:25:41 UTC, altitude: 1255.03 km
# ONEWEB-0367 culminate at 2025-01-07 17:22:26 UTC, altitude: 1245.86 km
# ONEWEB-0363 culminate at 2025-01-07 17:24:42 UTC, altitude: 1232.41 km
# ONEWEB-0530 culminate at 2025-01-07 17:26:58 UTC, altitude: 1221.24 km
# HONGYUN 1 culminate at 2025-01-07 17:16:48 UTC, altitude: 1218.30 km
# ONEWEB-0360 culminate at 2025-01-07 17:29:14 UTC, altitude: 1211.19 km
# ONEWEB-0672 culminate at 2025-01-07 17:31:33 UTC, altitude: 1202.50 km
# ONEWEB-0524 culminate at 2025-01-07 17:33:47 UTC, altitude: 1196.66 km
# TIANQI 31 culminate at 2025-01-07 17:31:44 UTC, altitude: 1192.22 km
# ONEWEB-0370 culminate at 2025-01-07 17:36:01 UTC, altitude: 1192.01 km
# ONEWEB-0669 culminate at 2025-01-07 17:38:19 UTC, altitude: 1188.62 km
# IRIDIUM 168 culminate at 2025-01-07 17:28:54 UTC, altitude: 1170.66 km
# CUBESAT XI-IV (CO-57) culminate at 2025-01-07 17:31:51 UTC, altitude: 1167.56 km
# IRIDIUM 176 culminate at 2025-01-07 17:24:34 UTC, altitude: 1165.15 km
# BRITE-AUSTRIA culminate at 2025-01-07 17:15:06 UTC, altitude: 1114.67 km
# COSMOS 2517 (GEO-IK 2) culminate at 2025-01-07 17:27:01 UTC, altitude: 1086.48 km
# SHIYAN 23 (SY-23) culminate at 2025-01-07 17:34:04 UTC, altitude: 1072.18 km
# YUNHAI-3 02 culminate at 2025-01-07 17:20:02 UTC, altitude: 1060.55 km
# CHECKMATE 8 culminate at 2025-01-07 17:35:54 UTC, altitude: 1058.17 km
# IRIDIUM 180 culminate at 2025-01-07 17:38:07 UTC, altitude: 1040.42 km
# GAOFEN-3 02 culminate at 2025-01-07 17:27:13 UTC, altitude: 1031.73 km
# IRIDIUM 170 culminate at 2025-01-07 17:33:32 UTC, altitude: 1026.92 km
# CHUANGXIN 1-02 (CX-1-02) culminate at 2025-01-07 17:16:54 UTC, altitude: 1023.60 km
# ORBCOMM FM114 culminate at 2025-01-07 17:32:20 UTC, altitude: 951.68 km
# CHUANGXIN 1-03 (CX-1-03) culminate at 2025-01-07 17:21:15 UTC, altitude: 950.64 km
# SHERPA-LTC2 culminate at 2025-01-07 17:30:22 UTC, altitude: 940.03 km
# CAPELLA-11 (ACADIA-1) culminate at 2025-01-07 17:21:58 UTC, altitude: 924.50 km
# SAOCOM 1A culminate at 2025-01-07 17:25:55 UTC, altitude: 890.92 km
# HAISHAO-1 culminate at 2025-01-07 17:18:24 UTC, altitude: 875.67 km
# AEROCUBE 6A culminate at 2025-01-07 17:20:32 UTC, altitude: 875.37 km
# LEMUR-2-PETERG culminate at 2025-01-07 17:17:49 UTC, altitude: 857.11 km
# YUNHAI-1 02 culminate at 2025-01-07 17:20:17 UTC, altitude: 812.52 km
# 2024-105E culminate at 2025-01-07 17:24:37 UTC, altitude: 751.62 km
# FLYING LAPTOP culminate at 2025-01-07 17:25:56 UTC, altitude: 748.95 km
# TECHNOSAT culminate at 2025-01-07 17:28:50 UTC, altitude: 746.75 km
# HELIOS 2A culminate at 2025-01-07 17:26:53 UTC, altitude: 741.91 km
# DEIMOS-1 culminate at 2025-01-07 17:26:56 UTC, altitude: 741.04 km
# SNIPE 4 culminate at 2025-01-07 17:39:36 UTC, altitude: 738.38 km
# SHIJIAN-6 01A (SJ-6 01A) culminate at 2025-01-07 17:19:55 UTC, altitude: 734.46 km
# NORSAT 1 culminate at 2025-01-07 17:39:56 UTC, altitude: 722.19 km
# M3MSAT culminate at 2025-01-07 17:33:47 UTC, altitude: 701.62 km
# TIANMU-1 11 culminate at 2025-01-07 17:34:06 UTC, altitude: 698.00 km
# GAOFEN-12 01 culminate at 2025-01-07 17:27:44 UTC, altitude: 695.04 km
# HJ-2F culminate at 2025-01-07 17:17:38 UTC, altitude: 683.87 km
# GEESAT-2 07 culminate at 2025-01-07 17:33:14 UTC, altitude: 681.61 km
# PATHFINDER 1 culminate at 2025-01-07 17:19:10 UTC, altitude: 677.91 km
# JILIN-1 culminate at 2025-01-07 17:30:53 UTC, altitude: 663.82 km
# WNISAT-1 culminate at 2025-01-07 17:25:30 UTC, altitude: 658.21 km
# KINEIS-1A culminate at 2025-01-07 17:27:40 UTC, altitude: 657.93 km
# YAOGAN-10 culminate at 2025-01-07 17:29:32 UTC, altitude: 655.53 km
# GENESIS 2 culminate at 2025-01-07 17:16:34 UTC, altitude: 651.52 km
# GEESAT-2 06 culminate at 2025-01-07 17:32:36 UTC, altitude: 645.29 km
# NANOACE culminate at 2025-01-07 17:20:09 UTC, altitude: 619.71 km
# XIAOXIANG 4 culminate at 2025-01-07 17:17:49 UTC, altitude: 616.76 km
# STARS-AO culminate at 2025-01-07 17:30:30 UTC, altitude: 602.24 km
# M2 PATHFINDER culminate at 2025-01-07 17:38:29 UTC, altitude: 598.81 km
# CORVUS BC1 culminate at 2025-01-07 17:17:10 UTC, altitude: 572.28 km
# JILIN-1 03 culminate at 2025-01-07 17:29:13 UTC, altitude: 568.98 km
# SONATE culminate at 2025-01-07 17:19:38 UTC, altitude: 549.94 km
# GLOBAL-9 culminate at 2025-01-07 17:24:40 UTC, altitude: 539.87 km
# TIANMU-1 18 culminate at 2025-01-07 17:27:10 UTC, altitude: 538.08 km
# SHIYAN 6 01 (SY-6 01) culminate at 2025-01-07 17:21:21 UTC, altitude: 516.95 km
# 2023-193A culminate at 2025-01-07 17:23:40 UTC, altitude: 381.24 km
# DOT-1 culminate at 2025-01-07 17:23:08 UTC, altitude: 319.97 km

# %%
# Function to download TLE data from CelesTrak
def download_tle():
    url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=active&FORMAT=tle'
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful
    tle_lines = response.text.strip().splitlines()
    return tle_lines

# Load satellites using EarthSatellite class (only GLOBALSTAR satellites)
def load_satellites(tle_lines):
    satellites = []
    for i in range(0, len(tle_lines), 3):
        name = tle_lines[i].strip()
        if "GLOBALSTAR" in name.upper():  # Include only GLOBALSTAR satellites
            line1 = tle_lines[i + 1].strip()
            line2 = tle_lines[i + 2].strip()
            satellite = EarthSatellite(line1, line2, name, load.timescale())
            satellites.append(satellite)
    return satellites

# Function to predict satellite passes (rise, culmination, set) for a given location and time range
def predict_passes(satellites, location, start_time, end_time):
    ts = load.timescale()
    observer = Topos(latitude_degrees=location[0], longitude_degrees=location[1])

    results = []  # List to store results for sorting
    print(f"Predicting satellite passes for location: {location}")
    for satellite in satellites:
        t, events = satellite.find_events(observer, start_time, end_time, altitude_degrees=30.0)
        pass_info = {"name": satellite.name, "rise": None, "culminate": None, "set": None}

        for ti, event in zip(t, events):
            # Convert the Skyfield time object to a datetime and apply UTC+1 offset
            #ti_dt = ti.utc_datetime() + timedelta(hours=1)

            if event == 0:  # 0 corresponds to 'rise'
                pass_info["rise"] = ti.utc_strftime('%Y-%m-%d %H:%M:%S')
            elif event == 1:  # 1 corresponds to 'culminate'
                # Calculate satellite altitude during culmination
                difference = satellite - observer
                topocentric = difference.at(ti)
                altitude = topocentric.distance().km  # Altitude in kilometers
                pass_info["culminate"] = (ti.utc_strftime('%Y-%m-%d %H:%M:%S'), altitude)
            elif event == 2:  # 2 corresponds to 'set'
                pass_info["set"] = ti.utc_strftime('%Y-%m-%d %H:%M:%S')

        # Append result only if all three events were found
        if pass_info["rise"] and pass_info["culminate"] and pass_info["set"]:
            results.append(pass_info)

    # Display results
    for pass_info in results:
        rise = pass_info["rise"]
        culmination_time, altitude = pass_info["culminate"]
        set_time = pass_info["set"]
        print(f"{pass_info['name']}:\n"
              f"  Rise:       {rise} UTC\n"
              f"  Culminate:  {culmination_time} UTC, altitude: {altitude:.2f} km\n"
              f"  Set:        {set_time} UTC\n")

from datetime import timedelta

# Function to predict satellite passes (rise, culmination, set) for a given location and time range
def predict_passes(satellites, location, start_time, end_time):
    ts = load.timescale()
    observer = Topos(latitude_degrees=location[0], longitude_degrees=location[1])

    results = []  # List to store results for sorting
    print(f"Predicting satellite passes for location: {location}")
    for satellite in satellites:
        t, events = satellite.find_events(observer, start_time, end_time, altitude_degrees=30.0)
        pass_info = {"name": satellite.name, "rise": None, "culminate": None, "set": None}

        for ti, event in zip(t, events):
            # Convert the Skyfield time object to a datetime and apply UTC+1 offset
            ti_dt = ti.utc_datetime() + timedelta(hours=1)

            if event == 0:  # 0 corresponds to 'rise'
                pass_info["rise"] = ti_dt.strftime('%Y-%m-%d %H:%M:%S')
            elif event == 1:  # 1 corresponds to 'culminate'
                # Calculate satellite altitude during culmination
                difference = satellite - observer
                topocentric = difference.at(ti)
                altitude = topocentric.distance().km  # Altitude in kilometers
                pass_info["culminate"] = (ti_dt.strftime('%Y-%m-%d %H:%M:%S'), altitude)
            elif event == 2:  # 2 corresponds to 'set'
                pass_info["set"] = ti_dt.strftime('%Y-%m-%d %H:%M:%S')

        # Append result only if all three events were found
        if pass_info["rise"] and pass_info["culminate"] and pass_info["set"]:
            results.append(pass_info)

    # Display results
    for pass_info in results:
        rise = pass_info["rise"]
        culmination_time, altitude = pass_info["culminate"]
        set_time = pass_info["set"]
        print(f"{pass_info['name']}:\n"
              f"  Rise:       {rise} UTC+1\n"
              f"  Culminate:  {culmination_time} UTC+1, altitude: {altitude:.2f} km\n"
              f"  Set:        {set_time} UTC+1\n")

from datetime import datetime, timedelta

# Main function
if __name__ == "__main__":
    # Download and load TLE data
    #tle_lines = download_tle()
    satellites = load_satellites(tle_lines)

    # Set location for Zurich, Switzerland (latitude, longitude)
    location = (46.410556, 9.967222)

    # Set prediction time range in UTC+1 (user-friendly input)
    start_time_utc1 = datetime(2025, 1, 7, 16, 30, 0)  # 8 Jan 2025, 07:00 UTC+1
    end_time_utc1 = datetime(2025, 1, 7, 18, 0, 0)    # 8 Jan 2025, 08:00 UTC+1

    # Convert UTC+1 time to UTC by subtracting 1 hour
    start_time_utc = start_time_utc1 - timedelta(hours=1)
    end_time_utc = end_time_utc1 - timedelta(hours=1)

    # Use Skyfield to create time objects in UTC
    ts = load.timescale()
    start_time = ts.utc(start_time_utc.year, start_time_utc.month, start_time_utc.day,
                        start_time_utc.hour, start_time_utc.minute, start_time_utc.second)
    end_time = ts.utc(end_time_utc.year, end_time_utc.month, end_time_utc.day,
                      end_time_utc.hour, end_time_utc.minute, end_time_utc.second)

    # Predict satellite passes
    predict_passes(satellites, location, start_time, end_time)


""""
# Main function
if __name__ == "__main__":
    # Download and load TLE data
    #tle_lines = download_tle()
    satellites = load_satellites(tle_lines)

    # Set location for Zurich, Switzerland (latitude, longitude)
    location = (46.410556, 9.967222)

    # Set prediction time range (8 Jan 2025, 01:00 UTC to 8 Jan 2025, 02:00 UTC)
    ts = load.timescale()
    start_time = ts.utc(2025, 1, 8, 6, 00, 0)  # 8 Jan 2025, 01:00 UTC
    end_time = ts.utc(2025, 1, 8, 7, 00, 0)    # 8 Jan 2025, 02:00 UTC

    # Predict satellite passes
    predict_passes(satellites, location, start_time, end_time)
    """
# Out:
# Predicting satellite passes for location: (46.410556, 9.967222)
# GLOBALSTAR M069:
#   Rise:       2025-01-07 17:49:41 UTC+1
#   Culminate:  2025-01-07 17:54:45 UTC+1, altitude: 1455.84 km
#   Set:        2025-01-07 17:59:51 UTC+1
#
# GLOBALSTAR M079:
#   Rise:       2025-01-07 17:11:37 UTC+1
#   Culminate:  2025-01-07 17:16:14 UTC+1, altitude: 1582.15 km
#   Set:        2025-01-07 17:20:52 UTC+1
#
# GLOBALSTAR M076:
#   Rise:       2025-01-07 16:31:19 UTC+1
#   Culminate:  2025-01-07 16:35:58 UTC+1, altitude: 1573.22 km
#   Set:        2025-01-07 16:40:37 UTC+1
#
# GLOBALSTAR M075:
#   Rise:       2025-01-07 16:41:57 UTC+1
#   Culminate:  2025-01-07 16:46:43 UTC+1, altitude: 1496.04 km
#   Set:        2025-01-07 16:51:29 UTC+1
#
# GLOBALSTAR M073:
#   Rise:       2025-01-07 17:00:42 UTC+1
#   Culminate:  2025-01-07 17:05:31 UTC+1, altitude: 1476.43 km
#   Set:        2025-01-07 17:10:20 UTC+1
#
# GLOBALSTAR M092:
#   Rise:       2025-01-07 17:40:48 UTC+1
#   Culminate:  2025-01-07 17:45:05 UTC+1, altitude: 1677.31 km
#   Set:        2025-01-07 17:49:23 UTC+1
#
# GLOBALSTAR M094:
#   Rise:       2025-01-07 17:21:42 UTC+1
#   Culminate:  2025-01-07 17:26:39 UTC+1, altitude: 1419.37 km
#   Set:        2025-01-07 17:31:37 UTC+1
# '"\n# Main function\nif __name__ == "__main__":\n    # Download and load TLE data\n    #tle_lines = download_tle()\n    satellites = load_satellites(tle_lines)\n\n    # Set location for Zurich, Switzerland (latitude, longitude)\n    location = (46.410556, 9.967222)\n\n    # Set prediction time range (8 Jan 2025, 01:00 UTC to 8 Jan 2025, 02:00 UTC)\n    ts = load.timescale()\n    start_time = ts.utc(2025, 1, 8, 6, 00, 0)  # 8 Jan 2025, 01:00 UTC\n    end_time = ts.utc(2025, 1, 8, 7, 00, 0)    # 8 Jan 2025, 02:00 UTC\n\n    # Predict satellite passes\n    predict_passes(satellites, location, start_time, end_time)\n    '
